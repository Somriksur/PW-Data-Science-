# %% [markdown]
# 🧠 THEORY QUESTIONS
#
# 1. What is NumPy, and why is it widely used in Python
#    - NumPy is a powerful Python library for numerical computations.
#    - It provides efficient array operations and supports large, multi-dimensional arrays and matrices.
#
# 2. How does broadcasting work in NumPy
#    - Broadcasting allows NumPy to perform operations on arrays of different shapes.
#    - It stretches the smaller array to match the shape of the larger one.
#
# 3. What is a Pandas DataFrame
#    - A DataFrame is a 2D labeled data structure in Pandas.
#    - It is similar to a SQL table or Excel spreadsheet.
#
# 4. Explain the use of the groupby() method in Pandas
#    - groupby() splits data into groups, applies a function, and combines results.
#    - Useful for aggregation like sum, mean, count, etc.
#
# 5. Why is Seaborn preferred for statistical visualizations
#    - Seaborn builds on Matplotlib and provides easier syntax and attractive themes.
#    - Supports advanced statistical plots with less code.
#
# 6. What are the differences between NumPy arrays and Python lists
#    - NumPy arrays are faster and more memory efficient.
#    - Arrays support element-wise operations; lists do not.
#
# 7. What is a heatmap, and when should it be used
#    - A heatmap uses color to represent values in a matrix.
#    - Ideal for visualizing correlation matrices or frequency data.
#
# 8. What does the term “vectorized operation” mean in NumPy
#    - Vectorized operations allow operations over arrays without explicit loops.
#    - Improves performance and simplifies code.
#
# 9. How does Matplotlib differ from Plotly
#    - Matplotlib creates static, publication-quality plots.
#    - Plotly creates interactive, web-friendly plots.
#
# 10. What is the significance of hierarchical indexing in Pandas
#     - Allows multiple index levels for rows and columns.
#     - Useful for working with multi-dimensional data.
#
# 11. What is the role of Seaborn’s pairplot() function
#     - Creates scatter plots between all pairs of numerical variables.
#     - Useful for quick exploratory data analysis.
#
# 12. What is the purpose of the describe() function in Pandas
#     - Generates summary statistics (mean, std, min, etc.) for each column.
#
# 13. Why is handling missing data important in Pandas
#     - Missing data can bias analysis.
#     - Pandas provides tools to detect, fill, or drop missing values.
#
# 14. What are the benefits of using Plotly for data visualization
#     - Interactive charts that can be embedded in web apps.
#     - 3D and animated visualizations are supported.
#
# 15. How does NumPy handle multidimensional arrays
#     - Supports n-dimensional arrays using ndarray.
#     - Allows slicing, broadcasting, and reshaping.
#
# 16. What is the role of Bokeh in data visualization
#     - Bokeh provides interactive visualizations for the web.
#     - Good for dashboards and real-time streaming data.
#
# 17. Explain the difference between apply() and map() in Pandas
#     - map(): applies function element-wise on Series.
#     - apply(): applies function on Series or across rows/columns of DataFrames.
#
# 18. What are some advanced features of NumPy
#     - Broadcasting, masked arrays, linear algebra, FFT, memory mapping.
#
# 19. How does Pandas simplify time series analysis
#     - Provides datetime indexing, resampling, frequency conversion, and time offsets.
#
# 20. What is the role of a pivot table in Pandas
#     - Pivot tables summarize data using grouping and aggregation.
#
# 21. Why is NumPy’s array slicing faster than Python’s list slicing
#     - NumPy slicing returns views (not copies) and is implemented in C.
#
# 22. What are some common use cases for Seaborn?
#     - Distribution plots, categorical comparisons, correlation visualizations, and statistical relationships.
# """

# %%
#Theory
# 1. Create a 2D NumPy array and calculate the sum of each row
import numpy as np
import pandas as pd

df = pd.read_csv("/players.csv")
arr = df.select_dtypes(include=[np.number]).iloc[:5, :3].values  # take first 3 numeric columns and 5 rows
row_sums = arr.sum(axis=1)
print("2D Array:\n", arr)
print("Sum of each row:", row_sums)
# Out:
# 2D Array:
#  []
# Sum of each row: [0. 0. 0. 0. 0.]

# %%
# 2. Find the mean of a specific column in a DataFrame
df = pd.read_csv("/Bank_churn.csv")
mean_val = df['CreditScore'].mean()
print("Mean Credit Score:", mean_val)
# Out:
# Mean Credit Score: 650.5288

# %%
# 3. Create a scatter plot using Matplotlib
import matplotlib.pyplot as plt

plt.scatter(df['CreditScore'], df['Balance'])
plt.xlabel("Credit Score")
plt.ylabel("Balance")
plt.title("Scatter: Credit Score vs Balance")
plt.show()

# %%
# 4. Correlation matrix and heatmap using Seaborn
import seaborn as sns

corr = df[['CreditScore', 'Balance', 'EstimatedSalary']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# %%
# 5. Generate a bar plot using Plotly
import plotly.express as px

fig = px.bar(df, x='Geography', y='Balance', title='Average Balance by Geography', color='Geography')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# 6. Add a new column based on an existing one
df['Balance_Squared'] = df['Balance'] ** 2
print(df[['Balance', 'Balance_Squared']].head())
# Out:
#      Balance  Balance_Squared
# 0       0.00     0.000000e+00
# 1   83807.86     7.023757e+09
# 2  159660.80     2.549157e+10
# 3       0.00     0.000000e+00
# 4  125510.82     1.575297e+10

# %%
# 7. Perform element-wise multiplication of two NumPy arrays
arr1 = np.array([10, 20, 30])
arr2 = np.array([2, 3, 4])
print("Multiplication:", arr1 * arr2)
# Out:
# Multiplication: [ 20  60 120]

# %%
# 8. Line plot with multiple lines using Matplotlib
x = range(10)
plt.plot(x, df['CreditScore'].head(10), label='Credit Score')
plt.plot(x, df['Balance'].head(10), label='Balance')
plt.legend()
plt.title("Line Plot: Credit Score and Balance")
plt.show()

# %%
# 9. Filter rows where a column value is greater than a threshold
high_balance = df[df['Balance'] > 100000]
print(high_balance[['CustomerId', 'Balance']].head())
# Out:
#    CustomerId    Balance
# 2    15619304  159660.80
# 4    15737888  125510.82
# 5    15574012  113755.78
# 7    15656148  115046.74
# 8    15792365  142051.07

# %%
# 10. Histogram using Seaborn
sns.histplot(df['EstimatedSalary'], kde=True)
plt.title("Estimated Salary Distribution")
plt.show()

# %%
# 11. Matrix multiplication using NumPy
mat1 = np.array([[1, 2], [3, 4]])
mat2 = np.array([[2, 0], [1, 2]])
print("Matrix Multiplication:\n", np.dot(mat1, mat2))
# Out:
# Matrix Multiplication:
#  [[ 4  4]
#  [10  8]]

# %%
# 12. Load a CSV and display its first 5 rows
services_df = pd.read_csv("/services.csv")
print(services_df.head())
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
# 13. Create a 3D scatter plot using Plotly
fig = px.scatter_3d(df, x='CreditScore', y='Balance', z='EstimatedSalary', color='Geography')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
