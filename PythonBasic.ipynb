# %% [markdown]
# 1) What is Python, and why is it popular ?
#
# --Python is a high-level, interpreted programming language known for its:
#
# Simple and readable syntax (easy to learn and write)
#
# Versatility (used in web development, data analysis, artificial intelligence, automation, etc.)
#
# Extensive standard library and active community support
#
# 🔹 Why Is Python Popular?
# Beginner-Friendly: Its syntax is close to plain English, making it ideal for beginners.
#
# Wide Use Cases:
#
# Web development (with Django, Flask)
#
# Data science and machine learning (with Pandas, NumPy, TensorFlow)
#
# Scripting and automation
#
# Game and app development
#
# Large Community: A vast support network, tutorials, and open-source packages.
#
# Cross-Platform: Runs on Windows, macOS, and Linux.
#
# Strong Integration: Works well with other languages and tools.
#
#
# 2) What is an interpreter in Python ?
#
#
# --An interpreter in Python is a program that reads and executes Python code line by line.
#
# Instead of converting the entire code into machine language at once (like a compiler), the Python interpreter processes each line one at a time, which makes it easier to:
#
# Debug (find and fix errors)
#
# Test code quickly
#
# Write scripts interactively
#
# 3) What are pre-defined keywords in Python ?
#
# -- What Are Pre-defined Keywords in Python?
# Pre-defined keywords in Python are reserved words that have special meaning in the language. You cannot use them as variable names, function names, or identifiers.
#
# They are part of Python’s syntax and structure and are recognized by the interpreter.
#
#  Examples of Python Keywords:
# if, else, elif – for conditional statements
#
# for, while – for loops
#
# def, return – for defining functions
#
# class – to define a class
#
# import, from, as – for importing modules
#
# True, False, None – special constants
#
# try, except, finally – for exception handling
#
# and, or, not – logical operators
#
# 4) 8 Can keywords be used as variable names ?
#
# --  No, keywords cannot be used as variable names in Python.
# Keywords are reserved by Python because they have special meanings and are part of the language’s syntax. Using them as variable names will result in a syntax error.
#
# 5) What is mutability in Python ?
#
# -- What Is Mutability in Python?
# Mutability refers to whether an object in Python can be changed after it is created.
#
# If an object can be changed, it is called mutable.
#
# If it cannot be changed, it is called immutable.
#
#  Examples of Mutable Objects:
# These objects can be modified in place.
#
# list
#
# dict (dictionary)
#
# set
#
#
# 6) Why are lists mutable, but tuples are immutable ?
#
# --In Python, lists are mutable because they are designed for storing collections of data that can change — you can add, remove, or modify elements. Tuples are immutable because they are intended for fixed data that should not change after creation, which improves performance, memory efficiency, and ensures data integrity. This immutability also allows tuples (if they contain only immutable items) to be used as dictionary keys, unlike lists.
#
# 7) What is the difference between “==” and “is” operators in Python ?
#
# --In Python, the == operator checks whether two variables have the same value, while the is operator checks whether two variables refer to the exact same object in memory. For example, a == b is True if a and b contain equal data, but a is b is True only if they point to the same memory location. This means == compares contents, and is compares identity.
#
# 8)  What are logical operators in Python ?
#
# --Logical Operators in Python
# Logical operators in Python are used to combine multiple conditions and return a Boolean value (True or False).
# The logical operators in Python are:
#
# and
#
# or
#
# not
#
# 9) What is type casting in Python ?
#
# --Type casting in Python is the process of converting one data type into another, such as converting a string to an integer, or a float to a string. This is done using built-in functions like int(), float(), str(), etc.
#
# 10) What is the difference between implicit and explicit type casting ?
#
# --Implicit type casting is automatically done by Python when it converts one data type to another during an operation (e.g., int to float).
# Explicit type casting is when the programmer manually converts a data type using functions like int(), float(), or str().
#
# 11) What is the purpose of conditional statements in Python ?
#
# --The purpose of conditional statements in Python is to control the flow of a program by executing certain blocks of code only when specific conditions are met. They help make decisions using statements like if, elif, and else.
#
# 12) How does the elif statement work ?
#
# --The elif (short for "else if") statement in Python is used to check multiple conditions after an initial if condition. If the if condition is False, Python checks each elif condition in order. The first elif that is True gets executed, and the rest are skipped. If none are True, the else block (if present) runs.
#
# 13) What is the difference between for and while loops ?
#
# --The for loop in Python is used when you want to iterate over a sequence (like a list, string, or range) a specific number of times, while the while loop is used when you want to repeat a block of code as long as a condition is true, without necessarily knowing how many times it will run.
#
# 14) Describe a scenario where a while loop is more suitable than a for loop ?
#
# --A while loop is more suitable than a for loop when you don’t know in advance how many times the loop needs to run — for example, when waiting for user input to meet a certain condition.
#
#  Example Scenario:
# You want to prompt a user to enter a password until they type the correct one:
#
# python
# Copy
# Edit
# correct_password = "python123"
# user_input = ""
#
# while user_input != correct_password:
#     user_input = input("Enter password: ")

# %%
# 1) Write a Python program to print "Hello, World!


print("Hello, World!")

# 2) Write a Python program that displays your name and age

name = "Somrik Sur"
age = 22  # Replace with your actual age

print("Name:", name)
print("Age:", age)

# 3) Write code to print all the pre-defined keywords in Python using the keyword library8

import keyword

print("Python Keywords:")
print(keyword.kwlist)

# 4) Write a program that checks if a given word is a Python keyword.

import keyword

word = input("Enter a word: ")

if keyword.iskeyword(word):
    print(f"'{word}' is a Python keyword.")
else:
    print(f"'{word}' is NOT a Python keyword.")

# 5)  Create a list and tuple in Python, and demonstrate how attempting to change an element works differently for each.

# Create a list and a tuple
my_list = [1, 2, 3]
my_tuple = (1, 2, 3)

# Modify the list
print("Original list:", my_list)
my_list[0] = 100
print("Modified list:", my_list)

# Attempt to modify the tuple
print("Original tuple:", my_tuple)
try:
    my_tuple[0] = 100  # This will raise an error
except TypeError as e:
    print("Error when modifying tuple:", e)

# 6) Write a function to demonstrate the behavior of mutable and immutable arguments.

def modify_data(num, my_list):
    num += 10            # Immutable: int (change won't affect original)
    my_list.append(100)  # Mutable: list (change will affect original)
    print("Inside function - num:", num)
    print("Inside function - my_list:", my_list)

# Immutable argument
x = 5

# Mutable argument
lst = [1, 2, 3]

modify_data(x, lst)

print("Outside function - x:", x)          # Unchanged
print("Outside function - lst:", lst)      # Changed

# 7)  Write a program that performs basic arithmetic operations on two user-input numbers.

# Get user input
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

# Perform arithmetic operations
print("Addition:", num1 + num2)
print("Subtraction:", num1 - num2)
print("Multiplication:", num1 * num2)

# Check for division by zero
if num2 != 0:
    print("Division:", num1 / num2)
else:
    print("Division: Cannot divide by zero")

# 8) Write a program to demonstrate the use of logical operators.

# Get user input
age = int(input("Enter your age: "))
has_ticket = input("Do you have a ticket? (yes/no): ").lower()

# Logical operator examples
# AND operator
if age >= 18 and has_ticket == "yes":
    print("You are allowed to enter.")

# OR operator
elif age >= 18 or has_ticket == "yes":
    print("Partial access granted. Conditions not fully met.")

# NOT operator
else:
    print("Access denied:", not (age >= 18 and has_ticket == "yes"))

# 9) Write a Python program to convert user input from string to integer, float, and boolean types.

# Get user input as a string
user_input = input("Enter a value: ")

# Convert to integer
try:
    int_value = int(user_input)
    print("Integer:", int_value)
except ValueError:
    print("Cannot convert to integer.")

# Convert to float
try:
    float_value = float(user_input)
    print("Float:", float_value)
except ValueError:
    print("Cannot convert to float.")

# Convert to boolean
bool_value = bool(user_input)
print("Boolean:", bool_value)

# 10) Write code to demonstrate type casting with list elements.

# Original list of strings
str_list = ['1', '2', '3', '4.5', '5.6']

# Convert string elements to integers where possible
int_list = []
for item in str_list:
    try:
        int_list.append(int(float(item)))  # Handles both integers and floats in string form
    except ValueError:
        int_list.append(None)  # Add None if conversion fails

print("Original list (strings):", str_list)
print("Converted list (integers):", int_list)

# 11) Write a program that checks if a number is positive, negative, or zero.

# Get user input
num = float(input("Enter a number: "))

# Check the number type
if num > 0:
    print("The number is positive.")
elif num < 0:
    print("The number is negative.")
else:
    print("The number is zero.")

# 12) Write a for loop to print numbers from 1 to 10.

for i in range(1, 11):
    print(i)

# 13) Write a Python program to find the sum of all even numbers between 1 and 50.

total = 0

for i in range(2, 51, 2):  # Start from 2, go up to 50, step by 2
    total += i

print("Sum of even numbers from 1 to 50 is:", total)

# 14)  Write a program to reverse a string using a while loop.

# Get user input
text = input("Enter a string: ")

# Initialize variables
reversed_text = ""
index = len(text) - 1

# Reverse the string using while loop
while index >= 0:
    reversed_text += text[index]
    index -= 1

print("Reversed string:", reversed_text)

# 15) Write a Python program to calculate the factorial of a number provided by the user using a while loop.

# Get user input
num = int(input("Enter a number: "))

# Initialize factorial result
factorial = 1
i = 1

# Check for valid input
if num < 0:
    print("Factorial is not defined for negative numbers.")
else:
    while i <= num:
        factorial *= i
        i += 1
    print(f"Factorial of {num} is: {factorial}")
# Out:
# Hello, World!
# Name: Somrik Sur
# Age: 22
# Python Keywords:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# Enter a word: eerrrr
# 'eerrrr' is NOT a Python keyword.
# Original list: [1, 2, 3]
# Modified list: [100, 2, 3]
# Original tuple: (1, 2, 3)
# Error when modifying tuple: 'tuple' object does not support item assignment
# Inside function - num: 15
# Inside function - my_list: [1, 2, 3, 100]
# Outside function - x: 5
# Outside function - lst: [1, 2, 3, 100]
# Enter first number: 2345
# Enter second number: 234
# Addition: 2579.0
# Subtraction: 2111.0
# Multiplication: 548730.0
# Division: 10.021367521367521
# Enter your age: 21
# Do you have a ticket? (yes/no): Yes
# You are allowed to enter.
# Enter a value: 32
# Integer: 32
# ...
